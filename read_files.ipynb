# %%
import pandas as pd

from bs4 import BeautifulSoup
from glob import glob
import os

# %%
def soup_html_parser(file_path):
    """Convert HTML text into a data object


    Args:
        file_path (str): file path

    Returns:
        bs4.BeautifulSoup: HTML syntax parsed
    """
    with open(file_path, encoding='utf-8') as file:
        text = file.read()

    return BeautifulSoup(text, 'html.parser')

# %%
with open('valid_files.txt', 'r') as f:
    valid_files = f.read().splitlines()

# %%
for indx, file_path in enumerate(valid_files):
    valid_files[indx] = file_path.replace('\\','/')

# %%
features = ['لون السيارة', 'نوع الوقود', 'أصل السيارة', 'رخصة السيارة',
            'نوع الجير', 'الزجاج', 'قوة الماتور', 'عداد السيارة',
            'عدد الركاب', 'وسيلة الدفع', 'معروضة', 'أصحاب سابقون', 'إضافات', 'price']
dataset = pd.DataFrame(columns=features)
int_features = ['قوة الماتور', 'عداد السيارة']

for file_path in valid_files:
    html_parsed = soup_html_parser(file_path)
    list_sample_features = []
    dict_row_df = dict.fromkeys(features)

    # extract <table> elements needed from the file
    tables_extracted = html_parsed.findAll('table', {'class':['list_ads', 'driving-table']})

    # extraxt <td> elements included features from the second extracted table
    sample_features_html = tables_extracted[1].findAll('td')

    # extraxt target variable from the first extracted table
    price_sample = int((tables_extracted)[0].
                    find('h5', attrs={"class":"post-price"}).
                    text.split('\n')[0].split(' ')[0])

    # extraxt features names from each html element and append it to a list 
    for feature_value in sample_features_html:
        list_sample_features.append(feature_value.text)

    # create dictionary of features values for one sample
    for indx, val in enumerate(list_sample_features):
        if val in features:
            dict_row_df[val] = list_sample_features[indx+1]
    
    # set dependent variable value in dictionary for one sample
    dict_row_df['price'] = price_sample

    # insert a new sample to the dataframe
    dataset.loc[len(dataset)] = dict_row_df

# %%
dataset
# Out:
#      لون السيارة نوع الوقود أصل السيارة رخصة السيارة       نوع الجير  \
# 0     أبيض عاجي      بنزين       خصوصي     فلسطينية       اوتوماتيك
# 1          سكني       ديزل       خصوصي     فلسطينية   نصف اوتوماتيك
# 2          سكني      بنزين       خصوصي     فلسطينية       اوتوماتيك
# 3           بيج      بنزين       خصوصي     فلسطينية            عادي
# 4           فضي      بنزين       خصوصي     فلسطينية       اوتوماتيك
# ...          ...        ...         ...          ...             ...
# 6859     فيراني     كهرباء       خصوصي     فلسطينية       اوتوماتيك
# 6860       أبيض       ديزل       عمومي     فلسطينية            عادي
# 6861        فضي       ديزل       خصوصي     فلسطينية            عادي
# 6862     بترولي       ديزل       خصوصي     فلسطينية       اوتوماتيك
# 6863       أبيض       ديزل       عمومي     فلسطينية            عادي
#
#          الزجاج قوة الماتور عداد السيارة عدد الركاب       وسيلة الدفع  \
# 0     الكتروني        2000        75000        4+1          نقدا فقط
# 1     الكتروني        2500       130000        7+1   إمكانية التقسيط
# 2     الكتروني        1600          None       None         نقدا فقط
# 3         يدوي         906         شغال       4+1    إمكانية التقسيط
# 4     الكتروني        1200        38000        4+1          نقدا فقط
# ...         ...         ...          ...        ...               ...
# 6859  الكتروني        1000       130000        4+1   إمكانية التقسيط
# 6860  الكتروني        2400        00000        7+1          نقدا فقط
# 6861  الكتروني        1600        50000        4+1          نقدا فقط
# 6862  الكتروني        2200          100        6+1          نقدا فقط
# 6863  الكتروني        2500      7686866        7+1          نقدا فقط
#
#                  معروضة أصحاب سابقون  \
# 0            للبيع فقط      يد اولى
# 1     للبيع أو التبديل            2
# 2            للبيع فقط          None
# 3            للبيع فقط          00
# 4            للبيع فقط          None
# ...                 ...          ...
# 6859         للبيع فقط            2
# 6860         للبيع فقط            5
# 6861         للبيع فقط       يد صفر
# 6862         للبيع فقط        ثانيه
# 6863  للبيع أو التبديل        خامسة
#
#                                                  إضافات   price
# 0     \n\nمُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\n...  100000
# 1     \n\nمُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\n...   60000
# 2     \n\nمُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\n...   43500
# 3                               \n\nمُكيّف\nمسجل CD\n\n    5500
# 4     \n\nمُكيّف\nإغلاق مركزي\nجهاز إنذار\nجنطات مغن...   54000
# ...                                                 ...     ...
# 6859  \n\nمُكيّف\nإغلاق مركزي\nجهاز إنذار\nجنطات مغن...   45000
# 6860                                             \n\n\n   48000
# 6861  \n\nمُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\n...   87000
# 6862  \n\nمُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\n...  126000
# 6863               \n\nمُكيّف\nإغلاق مركزي\nمسجل CD\n\n   28000
#
# [6864 rows x 14 columns]

# %%
dataset.to_csv('./data_df/dataset_df__13-features__price.csv', index=False)
